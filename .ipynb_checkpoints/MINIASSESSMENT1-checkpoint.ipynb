# %%
#importing essential libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = pd.read_csv('data1.dat')
data2 = pd.read_csv('data2.dat')
data3 = pd.read_csv('data3.csv')

# %%
# data1
# Out:
#         1.90743
# 0      0.545265
# 1     -1.249300
# 2      1.306820
# 3      0.203998
# 4      5.248110
# ...         ...
# 49994  1.967580
# 49995  2.940000
# 49996  3.124900
# 49997  7.067150
# 49998  0.594597
#
# [49999 rows x 1 columns]

# %%
data11
# Out:
# array([[ 0.545265],
#        [-1.2493  ],
#        [ 1.30682 ],
#        ...,
#        [ 3.1249  ],
#        [ 7.06715 ],
#        [ 0.594597]])

# %%
data11 = data1.to_numpy()
n=len(data1)
print('The length of the data1.dat file is : ',n)
myrang = max(data11)-min(data11)
print('The range of the data1.dat file is : ',myrang)


#Using square root formula
number_of_intervals = np.sqrt(n)
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])

binning = np.arange(min(data11), max(data11) + width, width)


# plt.xlabel("age")
# plt.ylabel("counts")
plt.title('histogram using sqrt formula')
 
plt.hist(data11, bins =binning)
plt.show()
# Out:
# The length of the data1.dat file is :  49999
# The range of the data1.dat file is :  [14.12592]
# The width is :  [0.06317367]

# %%
#using rice formula
number_of_intervals = 2*(np.cbrt(n))
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])
binning = np.arange(min(data11), max(data11) + width, width)

    
    
# plt.xlabel("age")
# plt.ylabel("counts")
plt.title('histogram using rice formula')
 
plt.hist(data11, bins =binning)
plt.show()
# Out:
# The width is :  [0.19171951]

# %%
#using sturges formula
number_of_intervals = 1+(np.log2(n))
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])

binning = np.arange(min(data11), max(data11) + width, width)


    
#plt.xlabel("age")
#plt.ylabel("counts")
plt.title('histogram using sturges formula')
 
plt.hist(data11, bins =binning,range=myrang)
plt.show()
# Out:
# The width is :  [0.8504666]

# %%
from statistics import mode
print('Mode of the data is : ',data1.mode())
# Out:
# Mode of the data is :     1.90743
# 0 -1.79376
# 1 -1.29919
# 2 -1.02170
# 3  1.43912
# 4  1.63859
# 5  2.33086
# 6  2.67122
# 7  3.34357
# 8  6.88661

# %%
mean1 = sum(data11)/len(data11)
print('Mean of the data is : ',mean1)

from statistics import mean
print('The mean of the data1 is : ',data11.mean())
# Out:
# Mean of the data is :  [1.87179007]
# The mean of the data1 is :  1.871790071935765

# %%
data1.mean()
# Out:
# 1.90743    1.87179
# dtype: float64

# %%
print('Variance of data1 is :',data11.var())
# Out:
# Variance of data1 is : 8.4171191586038

# %%
from scipy.stats import skew
print('Skew of data1 is : ',data1.skew())
# Out:
# Skew of data1 is :  1.90743    0.768396
# dtype: float64

# %%
sk = data1.skew()

# %%
data2
# Out:
#        44.2253     23.459
# 0       45.3181  23.53950
# 1       44.5577  25.37700
# 2       45.6981  23.67750
# 3       15.5723   7.43368
# 4       29.4772  11.41550
# ...         ...       ...
# 49994   48.6187  25.59830
# 49995   46.7901  21.51350
# 49996   41.3364  18.56610
# 49997   45.7244  29.95480
# 49998   34.9793  17.44680
#
# [49999 rows x 2 columns]

# %%
data22 = data2.to_numpy()
# n=len(data2)
# print('The length of the data1.dat file is : ',n)
# myrang2 = max(data22)-min(data22)
# print('The range of the data1.dat file is : ',myrang)


# #Using square root formula
# number_of_intervals2 = np.sqrt(n)
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])

# binning2 = np.arange(min(data22), max(data22) + width2, width2)


# # plt.xlabel("age")
# # plt.ylabel("counts")
# plt.title('histogram using sqrt formula')
 
# plt.hist(data22, bins =binning)
# plt.show()
# Out:
# The length of the data1.dat file is :  49999
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 n=len(data2)
#       3 print('The length of the data1.dat file is : ',n)
# ----> 4 myrang2 = max(data22)-min(data22)
#       5 print('The range of the data1.dat file is : ',myrang)
#       8 #Using square root formula
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
plt.hist(data1)
# Out:
# (array([  338.,  4999., 10987., 10483.,  7881.,  5429.,  3804.,  2721.,
#          1880.,  1477.]),
#  array([-4.12755 , -2.714958, -1.302366,  0.110226,  1.522818,  2.93541 ,
#          4.348002,  5.760594,  7.173186,  8.585778,  9.99837 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data2)
# Out:
# (array([[1.1000e+01, 8.0000e+01, 3.0000e+02, 7.8300e+02, 1.5970e+03,
#          3.1370e+03, 5.1430e+03, 8.2700e+03, 1.2682e+04, 1.7996e+04],
#         [1.7400e+02, 1.4880e+03, 5.7460e+03, 1.5643e+04, 2.0540e+04,
#          6.0530e+03, 3.4900e+02, 6.0000e+00, 0.0000e+00, 0.0000e+00]]),
#  array([ 2.30178 ,  7.071592, 11.841404, 16.611216, 21.381028, 26.15084 ,
#         30.920652, 35.690464, 40.460276, 45.230088, 49.9999  ]),
#  <a list of 2 BarContainer objects>)

# %%
# #using rice formula
# number_of_intervals2 = 2*(np.cbrt(n))
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])
# binning2 = np.arange(min(data22), max(data22) + width2, width2)

    
    
# # plt.xlabel("age")
# # plt.ylabel("counts")
# plt.title('histogram using rice formula')
 
# plt.hist(data22, bins =binning2)
# plt.show()

# %%
# #using sturges formula
# number_of_intervals2 = 1+(np.log2(n))
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])

# binning2 = np.arange(min(data22), max(data22) + width2, width2)


    
# #plt.xlabel("age")
# #plt.ylabel("counts")
# plt.title('histogram using sturges formula')
 
# plt.hist(data22, bins =binning,range=myrang2)
# plt.show()

# %%
print('Mean of data2 is : ',data22.mean())
print('Variance of data2 is : ',data22.var())


from statistics import covariance

print("Covariance of data2 is : ",data22.covariance(data2[44.2253],data2[23.459]))
# Out:
# Mean of data2 is :  31.077829201884036
# Variance of data2 is :  134.55463592875813
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 7
#       2 print('Variance of data2 is : ',data22.var())
#       5 from statistics import covariance
# ----> 7 print("Covariance of data2 is : ",data22.covariance(data2[44.2253],data2[23.459]))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'covariance'

# %%
# Separate data into two dimensions
x_data = data2.iloc[:, 0]
y_data = data2.iloc[:, 1]

# Plot Histogram
plt.hist(data2, bins=20)
#plt.colorbar()
plt.title('2D Histogram of data2.dat')
plt.xlabel('X Dimension')
plt.ylabel('Y Dimension')
plt.show()

# Calculate Means
mean_x = np.mean(x_data)
mean_y = np.mean(y_data)

# Calculate Variances
var_x = np.var(x_data)
var_y = np.var(y_data)

# Calculate Covariance and Pearson Coefficient
cov_xy = np.cov(x_data, y_data)[0, 1]
pearson_coefficient = cov_xy / (np.sqrt(var_x) * np.sqrt(var_y))

# Display Results
print(f'Mean of X Dimension: {mean_x}')
print(f'Mean of Y Dimension: {mean_y}')
print(f'Variance of X Dimension: {var_x}')
print(f'Variance of Y Dimension: {var_y}')
print(f'Covariance: {cov_xy}')
print(f'Pearson Coefficient: {pearson_coefficient}')

# Discussion
print("\nDiscussion:")
print("The histogram provides an overview of the data distribution. The means give the central tendency of each dimension, and variances indicate the spread. Covariance and Pearson coefficient help understand the relationship between the two dimensions.")
# Out:
# Mean of X Dimension: 40.83843891437829
# Mean of Y Dimension: 21.317219489389792
# Variance of X Dimension: 58.11633172339201
# Variance of Y Dimension: 20.453936214849886
# Covariance: 28.866593049005537
# Pearson Coefficient: 0.8372554516968186
#
# Discussion:
# The histogram provides an overview of the data distribution. The means give the central tendency of each dimension, and variances indicate the spread. Covariance and Pearson coefficient help understand the relationship between the two dimensions.
