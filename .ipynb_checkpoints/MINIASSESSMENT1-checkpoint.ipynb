# %%
#importing essential libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = np.loadtxt('data1.dat')
data2 = np.loadtxt('data2.dat',delimiter=',')
data3 = pd.read_csv('data3.csv')

# %%
# data1

# %%
data1
# Out:
# array([ 1.90743 ,  0.545265, -1.2493  , ...,  3.1249  ,  7.06715 ,
#         0.594597])

# %%
#data11 = data1.to_numpy()
n=len(data1)
print('The length of the data1.dat file is : ',n)
myrang = max(data1)-min(data1)
print('The range of the data1.dat file is : ',myrang)


#Using square root formula
number_of_intervals = np.sqrt(n)
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])

binning = np.arange(min(data1), max(data1) + width, width)


# plt.xlabel("age")
# plt.ylabel("counts")
plt.title('histogram using sqrt formula')
 
plt.hist(data1, bins =binning)
plt.show()
# Out:
# The length of the data1.dat file is :  50000
# The range of the data1.dat file is :  14.12592
# The width is :  0.06317303472944766

# %%
#using rice formula
number_of_intervals = 2*(np.cbrt(n))
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])
binning = np.arange(min(data1), max(data1) + width, width)

    
    
# plt.xlabel("age")
# plt.ylabel("counts")
plt.title('histogram using rice formula')
 
plt.hist(data1, bins =binning)
plt.show()
# Out:
# The width is :  0.19171823049305162

# %%
#using sturges formula
number_of_intervals = 1+(np.log2(n))
width = myrang/number_of_intervals
print('The width is : ',width)
# binning=[]
# for i in range(int(number_of_intervals)):
#     binning.append(i*10)
#     print(i,binning[i])

binning = np.arange(min(data1), max(data1) + width, width)


    
#plt.xlabel("age")
#plt.ylabel("counts")
plt.title('histogram using sturges formula')
 
plt.hist(data1, bins =binning,range=myrang)
plt.show()
# Out:
# The width is :  0.850465127269949

# %%
# from statistics import mode
# print('Mode of the data is : ',data1.mode())

# %%
mean1 = sum(data1)/len(data1)
print('Mean of the data is : ',mean1)

from statistics import mean
print('The mean of the data1 is : ',data1.mean())
# Out:
# Mean of the data is :  1.8717907847343083
# The mean of the data1 is :  1.8717907847343263

# %%
data1.mean()
# Out:
# 1.8717907847343263

# %%
print('Variance of data1 is :',data1.var())
# Out:
# Variance of data1 is : 8.416950841624208

# %%
# from scipy.stats import skew
# print('Skew of data1 is : ',data1.skew())

# %%
# sk = data1.skew()

# %%
data2
# Out:
# array([[44.2253, 23.459 ],
#        [45.3181, 23.5395],
#        [44.5577, 25.377 ],
#        ...,
#        [41.3364, 18.5661],
#        [45.7244, 29.9548],
#        [34.9793, 17.4468]])

# %%
# data22 = data2.to_numpy()
# n=len(data2)
# print('The length of the data1.dat file is : ',n)
# myrang2 = max(data22)-min(data22)
# print('The range of the data1.dat file is : ',myrang)


# #Using square root formula
# number_of_intervals2 = np.sqrt(n)
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])

# binning2 = np.arange(min(data22), max(data22) + width2, width2)


# # plt.xlabel("age")
# # plt.ylabel("counts")
# plt.title('histogram using sqrt formula')
 
# plt.hist(data22, bins =binning)
# plt.show()

# %%
plt.hist(data1)
# Out:
# (array([  338.,  4999., 10987., 10483.,  7882.,  5429.,  3804.,  2721.,
#          1880.,  1477.]),
#  array([-4.12755 , -2.714958, -1.302366,  0.110226,  1.522818,  2.93541 ,
#          4.348002,  5.760594,  7.173186,  8.585778,  9.99837 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data2)
# Out:
# (array([[1.1000e+01, 8.0000e+01, 3.0000e+02, 7.8300e+02, 1.5970e+03,
#          3.1370e+03, 5.1430e+03, 8.2700e+03, 1.2683e+04, 1.7996e+04],
#         [1.7400e+02, 1.4880e+03, 5.7460e+03, 1.5643e+04, 2.0541e+04,
#          6.0530e+03, 3.4900e+02, 6.0000e+00, 0.0000e+00, 0.0000e+00]]),
#  array([ 2.30178 ,  7.071592, 11.841404, 16.611216, 21.381028, 26.15084 ,
#         30.920652, 35.690464, 40.460276, 45.230088, 49.9999  ]),
#  <a list of 2 BarContainer objects>)

# %%
# #using rice formula
# number_of_intervals2 = 2*(np.cbrt(n))
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])
# binning2 = np.arange(min(data22), max(data22) + width2, width2)

    
    
# # plt.xlabel("age")
# # plt.ylabel("counts")
# plt.title('histogram using rice formula')
 
# plt.hist(data22, bins =binning2)
# plt.show()

# %%
# #using sturges formula
# number_of_intervals2 = 1+(np.log2(n))
# width2 = myrang2/number_of_intervals2
# print('The width is : ',width2)
# # binning=[]
# # for i in range(int(number_of_intervals)):
# #     binning.append(i*10)
# #     print(i,binning[i])

# binning2 = np.arange(min(data22), max(data22) + width2, width2)


    
# #plt.xlabel("age")
# #plt.ylabel("counts")
# plt.title('histogram using sturges formula')
 
# plt.hist(data22, bins =binning,range=myrang2)
# plt.show()

# %%
# print('Mean of data2 is : ',data22.mean())
# print('Variance of data2 is : ',data22.var())


# from statistics import covariance

# print("Covariance of data2 is : ",data2.covariance(data2[44.2253],data2[23.459]))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew
# from scipy.stats import mode

# Load data from data1.dat
data = np.loadtxt('data1.dat')

# Plot Histogram
plt.hist(data, bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of data1.dat')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# Calculate Mean
mean_value = np.mean(data)
print(f'Mean: {mean_value}')

# # Calculate Mode
# mode_value = mode(data)
# print(f'Mode: {mode_value}')


# Calculate Variance
variance_value = np.var(data)
print(f'Variance: {variance_value}')

# Calculate Skew
skew_value = skew(data)
print(f'Skew: {skew_value}')
# Out:
# Mean: 1.8717907847343263
# Variance: 8.416950841624208
# Skew: 0.7683799624130743

# %%
# Separate data into two dimensions
x_data = data2[:, 0]
y_data = data2[:, 1]

# Plot Histogram
plt.hist(data2, bins=20)
#plt.colorbar()
plt.title('2D Histogram of data2.dat')
plt.xlabel('X Dimension')
plt.ylabel('Y Dimension')
plt.show()

# Calculate Means
mean_x = np.mean(x_data)
mean_y = np.mean(y_data)

# Calculate Variances
var_x = np.var(x_data)
var_y = np.var(y_data)

# Calculate Covariance and Pearson Coefficient
cov_xy = np.cov(x_data, y_data)[0, 1]
pearson_coefficient = cov_xy / (np.sqrt(var_x) * np.sqrt(var_y))

# Display Results
print(f'Mean of X Dimension: {mean_x}')
print(f'Mean of Y Dimension: {mean_y}')
print(f'Variance of X Dimension: {var_x}')
print(f'Variance of Y Dimension: {var_y}')
print(f'Covariance: {cov_xy}')
print(f'Pearson Coefficient: {pearson_coefficient}')

# Discussion
print("\nDiscussion:")
print("The histogram provides an overview of the data distribution. The means give the central tendency of each dimension, and variances indicate the spread. Covariance and Pearson coefficient help understand the relationship between the two dimensions.")
# Out:
# Mean of X Dimension: 40.83850665159999
# Mean of Y Dimension: 21.317262325000005
# Variance of X Dimension: 58.11539880872973
# Variance of Y Dimension: 20.453618878765763
# Covariance: 28.866160783858994
# Pearson Coefficient: 0.8372561290667033
#
# Discussion:
# The histogram provides an overview of the data distribution. The means give the central tendency of each dimension, and variances indicate the spread. Covariance and Pearson coefficient help understand the relationship between the two dimensions.

# %%
data3
# Out:
#            Var1  Var2      Var3  Var4      Var5
# 0    -10.000000   0.0  1.329637    13  0.004627
# 1     -9.797980   0.0  1.485366    75  0.004907
# 2     -9.595960   0.0  1.582144    83  1.085085
# 3     -9.393939   0.0  1.587533    68  0.359320
# 4     -9.191919   0.0  1.492111    39 -0.770488
# ...         ...   ...       ...   ...       ...
# 9995   9.191919  20.0  1.595110    84  0.180372
# 9996   9.393939  20.0  1.609941    81  0.146588
# 9997   9.595960  20.0  1.411719     3 -2.880569
# 9998   9.797980  20.0  1.029217    70 -0.516177
# 9999  10.000000  20.0  0.533843    70 -0.513992
#
# [10000 rows x 5 columns]
